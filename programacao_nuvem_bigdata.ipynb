# %% [markdown]
# Dentre as tecnologias de manipulação de dados presentes no mercado, destacam-se três: Pandas, Dask e Modin. Cada uma destas possui sua individualide e formas específicas de aplicação, cabendo ao profissional de dados interar-se e absorver conhecimentos sobre estas três ferramentas e possuir a capacidade de correta escolha quanto ao uso delas.
#
# Pandas é mais voltado ao trabalho com bases de dados de pequeno a médio porte. Tal limitação deve-se ao fato de que o dataset, quando processado no Pandas, deve caber na memória RAM do computador, assim como esta biblioteca não aproveita os múltiplos núcleos do processador e não lida com clusters.
# Para lidar com este problema, as seguintes bibliotecas abaixo são voltadas ao processamento exigente do Big Data:
#
# Dask - Fornece os DaskDataFrames, os quais possuem funcionamento parecido com os DataFrames tradicionais do Pandas. No entanto, o Dask consegue utilizar todos os núcleos da CPU ou atuar em cluster de computadores e possui a capacidade de executar as tarefas somente quando necessário (Lazy Execution);
#
# Modin - É tida como um substituto direto do Pandas, pois podemos usar o código Pandas que possuímos com a adição de paralelização da esmagadora maioria das operações. Ou seja, mesmo código pandas, só com distribuição das tarefas de processamento entre os vários núcleos do computador ou em clusters de computadores, possuindo ainda a possibilidade de trabalhar com datasets maiores que a RAM;

# %% [markdown]
# ## Aplicação do Pandas

# %%
import pandas as pd

# %%
base_pandas = pd.read_parquet("fortune1000_2024.parquet")  ## Download realizado a partir do Kaggle

# %%
base_pandas.head(3)
# Out:
#    Rank  Company Ticker      Sector                         Industry  \
# 0     1  Walmart    WMT   Retailing            General Merchandisers
# 1     2   Amazon   AMZN   Retailing  Internet Services and Retailing
# 2     3    Apple   AAPL  Technology      Computers, Office Equipment
#
#   Profitable Founder_is_CEO FemaleCEO Growth_in_Jobs  Change_in_Rank  ...  \
# 0        yes             no        no             no             0.0  ...
# 1        yes             no        no             no             0.0  ...
# 2        yes             no        no             no             1.0  ...
#
#    Assets_M                  CEO Country HeadquartersCity HeadquartersState  \
# 0  252399.0  C. Douglas McMillon    U.S.      Bentonville          Arkansas
# 1  527854.0      Andrew R. Jassy    U.S.          Seattle        Washington
# 2  352583.0      Timothy D. Cook    U.S.        Cupertino        California
#
#                          Website  CompanyType  \
# 0  https://www.stock.walmart.com       Public
# 1         https://www.amazon.com       Public
# 2          https://www.apple.com       Public
#
#                                             Footnote  MarketCap_Updated_M  \
# 0  Figures are for fiscal year ended Jan. 31, 202...             559911.0
# 1                  Market value as of July 15, 2024.            2005565.0
# 2  Figures are for fiscal year ended Sept. 30, 20...            3594309.0
#
#      Updated
# 0 2024-08-05
# 1 2024-08-05
# 2 2024-08-05
#
# [3 rows x 32 columns]

# %%
base_pandas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 32 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Rank                           1000 non-null   int64
#  1   Company                        1000 non-null   object
#  2   Ticker                         959 non-null    object
#  3   Sector                         1000 non-null   category
#  4   Industry                       1000 non-null   category
#  5   Profitable                     1000 non-null   category
#  6   Founder_is_CEO                 1000 non-null   category
#  7   FemaleCEO                      1000 non-null   category
#  8   Growth_in_Jobs                 1000 non-null   category
#  9   Change_in_Rank                 1000 non-null   float64
#  10  Gained_in_Rank                 1000 non-null   category
#  11  Dropped_in_Rank                1000 non-null   category
#  12  Newcomer_to_the_Fortune500     1000 non-null   category
#  13  Global500                      1000 non-null   category
#  14  Worlds_Most_Admired_Companies  1000 non-null   category
#  15  Best_Companies_to_Work_For     1000 non-null   category
#  16  Number_of_employees            1000 non-null   int64
#  17  MarketCap_March28_M            959 non-null    float64
#  18  Revenues_M                     1000 non-null   float64
#  19  RevenuePercentChange           994 non-null    float64
#  20  Profits_M                      998 non-null    float64
#  21  ProfitsPercentChange           850 non-null    float64
#  22  Assets_M                       1000 non-null   float64
#  23  CEO                            1000 non-null   object
#  24  Country                        1000 non-null   category
#  25  HeadquartersCity               1000 non-null   object
#  26  HeadquartersState              1000 non-null   category
#  27  Website                        1000 non-null   object
#  28  CompanyType                    1000 non-null   category
#  29  Footnote                       1000 non-null   object
#  30  MarketCap_Updated_M            963 non-null    float64
#  31  Updated                        1000 non-null   datetime64[ns]
# dtypes: category(15), datetime64[ns](1), float64(8), int64(2), object(6)
# memory usage: 153.8+ KB

# %%
base_pandas[base_pandas['Founder_is_CEO'] == "yes"].head(3)  ## fundados que são CEO's
# Out:
#     Rank            Company Ticker                  Sector  \
# 29    30     Meta Platforms   META              Technology
# 39    40              Tesla   TSLA  Motor Vehicles & Parts
# 47    48  Dell Technologies   DELL              Technology
#
#                            Industry Profitable Founder_is_CEO FemaleCEO  \
# 29  Internet Services and Retailing        yes            yes        no
# 39           Motor Vehicles & Parts        yes            yes        no
# 47      Computers, Office Equipment        yes            yes        no
#
#    Growth_in_Jobs  Change_in_Rank  ...  Assets_M              CEO Country  \
# 29             no             1.0  ...  229623.0  Mark Zuckerberg    U.S.
# 39            yes            10.0  ...  106618.0        Elon Musk    U.S.
# 47             no           -14.0  ...   82089.0  Michael S. Dell    U.S.
#
#    HeadquartersCity HeadquartersState                            Website  \
# 29       Menlo Park        California            https://investor.fb.com
# 39           Austin             Texas              https://www.tesla.com
# 47       Round Rock             Texas  https://www.delltechnologies.com/
#
#     CompanyType                                           Footnote  \
# 29       Public                  Market value as of July 15, 2024.
# 39       Public                  Market value as of July 15, 2024.
# 47       Public  Figures are for fiscal year ended Jan. 31, 202...
#
#     MarketCap_Updated_M    Updated
# 29            1258678.0 2024-08-05
# 39             805719.0 2024-08-05
# 47              97331.0 2024-08-05
#
# [3 rows x 32 columns]

# %%
base_pandas[base_pandas['HeadquartersState'] == "Texas"].head(3)  ## Companhias localizadas no estado americano do Texas
# Out:
#     Rank      Company Ticker       Sector                  Industry  \
# 6      7  Exxon Mobil    XOM       Energy        Petroleum Refining
# 8      9     McKesson    MCK  Health Care  Wholesalers: Health Care
# 25    26  Phillips 66    PSX       Energy        Petroleum Refining
#
#    Profitable Founder_is_CEO FemaleCEO Growth_in_Jobs  Change_in_Rank  ...  \
# 6         yes             no        no             no            -4.0  ...
# 8         yes             no        no             no             0.0  ...
# 25        yes             no        no            yes            -9.0  ...
#
#     Assets_M              CEO Country HeadquartersCity HeadquartersState  \
# 6   376317.0  Darren W. Woods    U.S.           Spring             Texas
# 8    62320.0   Brian S. Tyler    U.S.           Irving             Texas
# 25   75501.0  Mark E. Lashier    U.S.          Houston             Texas
#
#                        Website  CompanyType  \
# 6   https://www.exxonmobil.com       Public
# 8     https://www.mckesson.com       Public
# 25  https://www.phillips66.com       Public
#
#                                              Footnote  MarketCap_Updated_M  \
# 6   Excise taxes have been deducted. Market value ...             516824.0
# 8   Figures are for fiscal year ended March 31, 20...              75007.0
# 25  Excise taxes have been deducted. Market value ...              59383.0
#
#       Updated
# 6  2024-08-05
# 8  2024-08-05
# 25 2024-08-05
#
# [3 rows x 32 columns]

# %%
comp_estado = base_pandas.groupby('HeadquartersState')['Company'].count().reset_index().sort_values(by = 'Company', ascending=False)
comp_estado.head(10) ## Os dados estados com mais companhias
# Out:
# C:\Users\Ryan\AppData\Local\Temp\ipykernel_11680\3100898579.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   comp_estado = base_pandas.groupby('HeadquartersState')['Company'].count().reset_index().sort_values(by = 'Company', ascending=False)
#    HeadquartersState  Company
# 3         California      124
# 41             Texas      107
# 30          New York       78
# 12          Illinois       58
# 33              Ohio       51
# 36      Pennsylvania       45
# 8            Florida       39
# 44          Virginia       39
# 9            Georgia       37
# 20     Massachusetts       32
